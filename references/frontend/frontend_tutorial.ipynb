# %% [markdown]
# # SGLang Frontend Language

# %% [markdown]
# SGLang frontend language can be used to define simple and easy prompts in a convenient, structured way.

# %% [markdown]
# ## Launch A Server
#
# Launch the server in your terminal and wait for it to initialize.

# %%
from sglang import assistant_begin, assistant_end
from sglang import assistant, function, gen, system, user
from sglang import image
from sglang import RuntimeEndpoint
from sglang.lang.api import set_default_backend
from sglang.srt.utils import load_image
from sglang.test.doc_patch import launch_server_cmd
from sglang.utils import print_highlight, terminate_process, wait_for_server

server_process, port = launch_server_cmd(
    "python -m sglang.launch_server --model-path Qwen/Qwen2.5-7B-Instruct --host 0.0.0.0 --log-level warning"
)

wait_for_server(f"http://localhost:{port}")
print(f"Server started on http://localhost:{port}")
# Out:
# [2025-12-12 05:31:03] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2025-12-12 05:31:03] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2025-12-12 05:31:03] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [2025-12-12 05:31:09] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2025-12-12 05:31:09] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2025-12-12 05:31:09] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [2025-12-12 05:31:11] WARNING server_args.py:1416: Attention backend not explicitly specified. Use fa3 backend by default.
# [2025-12-12 05:31:16] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2025-12-12 05:31:16] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2025-12-12 05:31:16] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [2025-12-12 05:31:17] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2025-12-12 05:31:17] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2025-12-12 05:31:17] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1212 05:31:19.882187 861419 transfer_engine.cpp:486] Metrics reporting is disabled (set MC_TE_METRIC=1 to enable)
# I1212 05:31:19.882203 861419 transfer_engine.cpp:91] Transfer Engine parseHostNameWithPort. server_name: 10.184.97.146 port: 12001
# I1212 05:31:19.882227 861419 transfer_engine.cpp:146] Transfer Engine RPC using P2P handshake, listening on 10.184.97.146:15763
# I1212 05:31:19.882326 861419 transfer_engine.cpp:185] Auto-discovering topology...
# I1212 05:31:19.885319 861419 transfer_engine.cpp:200] Topology discovery complete. Found 9 HCAs.
# I1212 05:31:19.906988 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce0/
# I1212 05:31:19.907680 861419 rdma_context.cpp:126] RDMA device: mlx5_roce0, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:48:31:5d
# I1212 05:31:19.935356 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_eth0/
# I1212 05:31:19.936245 861419 rdma_context.cpp:126] RDMA device: mlx5_eth0, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:0a:b8:61:92
# I1212 05:31:19.962898 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce1/
# I1212 05:31:19.963511 861419 rdma_context.cpp:126] RDMA device: mlx5_roce1, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:48:b1:5d
# I1212 05:31:20.276000 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce2/
# I1212 05:31:20.276712 861419 rdma_context.cpp:126] RDMA device: mlx5_roce2, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:49:31:5d
# I1212 05:31:20.302922 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce3/
# I1212 05:31:20.303575 861419 rdma_context.cpp:126] RDMA device: mlx5_roce3, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:49:b1:5d
# I1212 05:31:20.330960 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce4/
# I1212 05:31:20.331614 861419 rdma_context.cpp:126] RDMA device: mlx5_roce4, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4a:31:5d
# I1212 05:31:20.358938 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce5/
# I1212 05:31:20.359571 861419 rdma_context.cpp:126] RDMA device: mlx5_roce5, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4a:b1:5d
# I1212 05:31:20.387041 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce6/
# I1212 05:31:20.387701 861419 rdma_context.cpp:126] RDMA device: mlx5_roce6, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4b:31:5d
# I1212 05:31:20.414953 861419 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce7/
# I1212 05:31:20.415593 861419 rdma_context.cpp:126] RDMA device: mlx5_roce7, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4b:b1:5d
# W1212 05:31:21.134250 861419 memory_location.cpp:72] Failed to get NUMA node, addr: 0x7f29dbfff010, len: 2147483648: Operation not permitted [1]
# [2025-12-12 05:31:23] Ignore import error when loading sglang.srt.models.mindspore: name 'ms' is not defined
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:00<00:02,  1.43it/s]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:01<00:01,  1.34it/s]
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [00:02<00:00,  1.21it/s]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.23it/s]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [00:03<00:00,  1.25it/s]
# Capturing batches (bs=4 avail_mem=62.79 GB):   0%|          | 0/3 [00:00<?, ?it/s]
# Capturing batches (bs=1 avail_mem=62.72 GB): 100%|██████████| 3/3 [00:00<00:00,  8.99it/s]
# [2025-12-12 05:31:32] Endpoint '/get_model_info' is deprecated and will be removed in a future version. Please use '/model_info' instead.
# <strong style='color: #00008B;'><br><br>                    NOTE: Typically, the server runs in a separate terminal.<br>                    In this notebook, we run the server and notebook code together, so their outputs are combined.<br>                    To improve clarity, the server logs are displayed in the original black color, while the notebook outputs are highlighted in blue.<br>                    To reduce the log length, we set the log level to warning for the server, the default log level is info.<br>                    We are running those notebooks in a CI environment, so the throughput is not representative of the actual performance.<br>                    </strong>
# Server started on http://localhost:39099

# %% [markdown]
# Set the default backend. Note: Besides the local server, you may use also `OpenAI` or other API endpoints.

# %%
set_default_backend(RuntimeEndpoint(f"http://localhost:{port}"))
# Out:
# [2025-12-12 05:31:37] Endpoint '/get_model_info' is deprecated and will be removed in a future version. Please use '/model_info' instead.

# %% [markdown]
# ## Basic Usage
#
# The most simple way of using SGLang frontend language is a simple question answer dialog between a user and an assistant.

# %%
@function
def basic_qa(s, question):
    s += system(f"You are a helpful assistant than can answer questions.")
    s += user(question)
    s += assistant(gen("answer", max_tokens=512))

# %%
state = basic_qa("List 3 countries and their capitals.")
print_highlight(state["answer"])
# Out:
# <strong style='color: #00008B;'>Sure! Here are three countries along with their capitals:<br><br>1. France - Paris<br>2. Italy - Rome<br>3. Japan - Tokyo</strong>

# %% [markdown]
# ## Multi-turn Dialog
#
# SGLang frontend language can also be used to define multi-turn dialogs.

# %%
@function
def multi_turn_qa(s):
    s += system(f"You are a helpful assistant than can answer questions.")
    s += user("Please give me a list of 3 countries and their capitals.")
    s += assistant(gen("first_answer", max_tokens=512))
    s += user("Please give me another list of 3 countries and their capitals.")
    s += assistant(gen("second_answer", max_tokens=512))
    return s


state = multi_turn_qa()
print_highlight(state["first_answer"])
print_highlight(state["second_answer"])
# Out:
# <strong style='color: #00008B;'>Certainly! Here's a list of three countries along with their capitals:<br><br>1. **France** - Paris<br>2. **Germany** - Berlin<br>3. **Italy** - Rome</strong>
# <strong style='color: #00008B;'>Of course! Here's another list of three countries along with their capitals:<br><br>1. **Spain** - Madrid<br>2. **Japan** - Tokyo<br>3. **Australia** - Canberra</strong>

# %% [markdown]
# ## Control flow
#
# You may use any Python code within the function to define more complex control flows.

# %%
@function
def tool_use(s, question):
    s += assistant(
        "To answer this question: "
        + question
        + ". I need to use a "
        + gen("tool", choices=["calculator", "search engine"])
        + ". "
    )

    if s["tool"] == "calculator":
        s += assistant("The math expression is: " + gen("expression"))
    elif s["tool"] == "search engine":
        s += assistant("The key word to search is: " + gen("word"))


state = tool_use("What is 2 * 2?")
print_highlight(state["tool"])
print_highlight(state["expression"])
# Out:
# <strong style='color: #00008B;'>calculator</strong>
# <strong style='color: #00008B;'>2 * 2.<br><br>Let's perform the calculation:<br><br>2 * 2 = 4<br><br>So, the result is 4. There's no need to use a calculator for this simple multiplication.</strong>

# %% [markdown]
# ## Parallelism
#
# Use `fork` to launch parallel prompts. Because `sgl.gen` is non-blocking, the for loop below issues two generation calls in parallel.

# %%
@function
def tip_suggestion(s):
    s += assistant(
        "Here are two tips for staying healthy: "
        "1. Balanced Diet. 2. Regular Exercise.\n\n"
    )

    forks = s.fork(2)
    for i, f in enumerate(forks):
        f += assistant(
            f"Now, expand tip {i+1} into a paragraph:\n"
            + gen("detailed_tip", max_tokens=256, stop="\n\n")
        )

    s += assistant("Tip 1:" + forks[0]["detailed_tip"] + "\n")
    s += assistant("Tip 2:" + forks[1]["detailed_tip"] + "\n")
    s += assistant(
        "To summarize the above two tips, I can say:\n" + gen("summary", max_tokens=512)
    )


state = tip_suggestion()
print_highlight(state["summary"])
# Out:
# <strong style='color: #00008B;'>1. **Balanced Diet**: Focus on eating a variety of nutrient-dense foods including fruits, vegetables, whole grains, lean proteins, and healthy fats. Be mindful of portion sizes and limit processed foods, sugars, and excess alcohol.<br><br>2. **Regular Exercise**: Aim for at least 150 minutes of moderate aerobic activity or 75 minutes of vigorous activity per week, and include strength training exercises at least two days a week. Choose activities you enjoy to maintain consistency and reap the benefits.<br><br>Both of these practices are essential for maintaining overall health and preventing various diseases.</strong>

# %% [markdown]
# ## Constrained Decoding
#
# Use `regex` to specify a regular expression as a decoding constraint. This is only supported for local models.

# %%
@function
def regular_expression_gen(s):
    s += user("What is the IP address of the Google DNS servers?")
    s += assistant(
        gen(
            "answer",
            temperature=0,
            regex=r"((25[0-5]|2[0-4]\d|[01]?\d\d?).){3}(25[0-5]|2[0-4]\d|[01]?\d\d?)",
        )
    )


state = regular_expression_gen()
print_highlight(state["answer"])
# Out:
# <strong style='color: #00008B;'>208.67.222.222</strong>

# %% [markdown]
# Use `regex` to define a `JSON` decoding schema.

# %%
character_regex = (
    r"""\{\n"""
    + r"""    "name": "[\w\d\s]{1,16}",\n"""
    + r"""    "house": "(Gryffindor|Slytherin|Ravenclaw|Hufflepuff)",\n"""
    + r"""    "blood status": "(Pure-blood|Half-blood|Muggle-born)",\n"""
    + r"""    "occupation": "(student|teacher|auror|ministry of magic|death eater|order of the phoenix)",\n"""
    + r"""    "wand": \{\n"""
    + r"""        "wood": "[\w\d\s]{1,16}",\n"""
    + r"""        "core": "[\w\d\s]{1,16}",\n"""
    + r"""        "length": [0-9]{1,2}\.[0-9]{0,2}\n"""
    + r"""    \},\n"""
    + r"""    "alive": "(Alive|Deceased)",\n"""
    + r"""    "patronus": "[\w\d\s]{1,16}",\n"""
    + r"""    "bogart": "[\w\d\s]{1,16}"\n"""
    + r"""\}"""
)


@function
def character_gen(s, name):
    s += user(
        f"{name} is a character in Harry Potter. Please fill in the following information about this character."
    )
    s += assistant(gen("json_output", max_tokens=256, regex=character_regex))


state = character_gen("Harry Potter")
print_highlight(state["json_output"])
# Out:
# <strong style='color: #00008B;'>{<br>    "name": "Harry Potter",<br>    "house": "Gryffindor",<br>    "blood status": "Half-blood",<br>    "occupation": "student",<br>    "wand": {<br>        "wood": "JNI",<br>        "core": "Phoenix feather",<br>        "length": 11.0<br>    },<br>    "alive": "Alive",<br>    "patronus": "Stag",<br>    "bogart": "Nicholas Flamel"<br>}</strong>

# %% [markdown]
# ## Batching
#
# Use `run_batch` to run a batch of prompts.

# %%
@function
def text_qa(s, question):
    s += user(question)
    s += assistant(gen("answer", stop="\n"))


states = text_qa.run_batch(
    [
        {"question": "What is the capital of the United Kingdom?"},
        {"question": "What is the capital of France?"},
        {"question": "What is the capital of Japan?"},
    ],
    progress_bar=True,
)

for i, state in enumerate(states):
    print_highlight(f"Answer {i+1}: {states[i]['answer']}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:00<00:00, 34.23it/s]
# <strong style='color: #00008B;'>Answer 1: The capital of the United Kingdom is London.</strong>
# <strong style='color: #00008B;'>Answer 2: The capital of France is Paris.</strong>
# <strong style='color: #00008B;'>Answer 3: The capital of Japan is Tokyo.</strong>

# %% [markdown]
# ## Streaming
#
# Use `stream` to stream the output to the user.

# %%
@function
def text_qa(s, question):
    s += user(question)
    s += assistant(gen("answer", stop="\n"))


state = text_qa.run(
    question="What is the capital of France?", temperature=0.1, stream=True
)

for out in state.text_iter():
    print(out, end="", flush=True)
# Out:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# What is the capital of France?<|im_end|>
# <|im_start|>assistant
# The
#  capital
#  of
#  France
#  is
#  Paris.
# <|im_end|>

# %% [markdown]
# ## Complex Prompts
#
# You may use `{system|user|assistant}_{begin|end}` to define complex prompts.

# %%
@function
def chat_example(s):
    s += system("You are a helpful assistant.")
    # Same as: s += s.system("You are a helpful assistant.")

    with s.user():
        s += "Question: What is the capital of France?"

    s += assistant_begin()
    s += "Answer: " + gen("answer", max_tokens=100, stop="\n")
    s += assistant_end()


state = chat_example()
print_highlight(state["answer"])
# Out:
# <strong style='color: #00008B;'> The capital of France is Paris.</strong>

# %%
terminate_process(server_process)

# %% [markdown]
# ## Multi-modal Generation
#
# You may use SGLang frontend language to define multi-modal prompts.
# See [here](https://docs.sglang.io/supported_models/generative_models.html) for supported models.

# %%
server_process, port = launch_server_cmd(
    "python -m sglang.launch_server --model-path Qwen/Qwen2.5-VL-7B-Instruct --host 0.0.0.0 --log-level warning"
)

wait_for_server(f"http://localhost:{port}")
print(f"Server started on http://localhost:{port}")
# Out:
# [2025-12-12 05:31:48] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2025-12-12 05:31:48] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2025-12-12 05:31:48] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [2025-12-12 05:31:50] WARNING server_args.py:1416: Attention backend not explicitly specified. Use flashinfer backend by default.
# [2025-12-12 05:31:57] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2025-12-12 05:31:57] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2025-12-12 05:31:57] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [2025-12-12 05:31:57] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2025-12-12 05:31:57] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2025-12-12 05:31:57] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1212 05:32:01.980808 862872 transfer_engine.cpp:486] Metrics reporting is disabled (set MC_TE_METRIC=1 to enable)
# I1212 05:32:01.980827 862872 transfer_engine.cpp:91] Transfer Engine parseHostNameWithPort. server_name: 10.184.97.146 port: 12001
# I1212 05:32:01.980851 862872 transfer_engine.cpp:146] Transfer Engine RPC using P2P handshake, listening on 10.184.97.146:16364
# I1212 05:32:01.980923 862872 transfer_engine.cpp:185] Auto-discovering topology...
# I1212 05:32:01.983835 862872 transfer_engine.cpp:200] Topology discovery complete. Found 9 HCAs.
# I1212 05:32:02.010914 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce0/
# I1212 05:32:02.011628 862872 rdma_context.cpp:126] RDMA device: mlx5_roce0, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:48:31:5d
# I1212 05:32:02.038430 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_eth0/
# I1212 05:32:02.039333 862872 rdma_context.cpp:126] RDMA device: mlx5_eth0, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:0a:b8:61:92
# I1212 05:32:02.066835 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce1/
# I1212 05:32:02.067487 862872 rdma_context.cpp:126] RDMA device: mlx5_roce1, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:48:b1:5d
# I1212 05:32:02.335979 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce2/
# I1212 05:32:02.336650 862872 rdma_context.cpp:126] RDMA device: mlx5_roce2, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:49:31:5d
# I1212 05:32:02.341500 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce3/
# I1212 05:32:02.342146 862872 rdma_context.cpp:126] RDMA device: mlx5_roce3, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:49:b1:5d
# I1212 05:32:02.366794 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce4/
# I1212 05:32:02.367429 862872 rdma_context.cpp:126] RDMA device: mlx5_roce4, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4a:31:5d
# I1212 05:32:02.394773 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce5/
# I1212 05:32:02.395419 862872 rdma_context.cpp:126] RDMA device: mlx5_roce5, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4a:b1:5d
# I1212 05:32:02.418896 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce6/
# I1212 05:32:02.419586 862872 rdma_context.cpp:126] RDMA device: mlx5_roce6, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4b:31:5d
# I1212 05:32:02.446810 862872 rdma_context.cpp:533] Find best gid index: 3 on mlx5_roce7/
# I1212 05:32:02.447467 862872 rdma_context.cpp:126] RDMA device: mlx5_roce7, LID: 0, GID: (GID_Index 3) 00:00:00:00:00:00:00:00:00:00:ff:ff:16:4b:b1:5d
# W1212 05:32:03.153712 862872 memory_location.cpp:72] Failed to get NUMA node, addr: 0x7fd307fff010, len: 2147483648: Operation not permitted [1]
# [2025-12-12 05:32:05] Ignore import error when loading sglang.srt.models.mindspore: name 'ms' is not defined
# Loading safetensors checkpoint shards:   0% Completed | 0/5 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  20% Completed | 1/5 [00:00<00:03,  1.18it/s]
# Loading safetensors checkpoint shards:  40% Completed | 2/5 [00:01<00:02,  1.28it/s]
# Loading safetensors checkpoint shards:  60% Completed | 3/5 [00:02<00:01,  1.24it/s]
# Loading safetensors checkpoint shards:  80% Completed | 4/5 [00:03<00:00,  1.36it/s]
# Loading safetensors checkpoint shards: 100% Completed | 5/5 [00:03<00:00,  1.81it/s]
# Loading safetensors checkpoint shards: 100% Completed | 5/5 [00:03<00:00,  1.53it/s]
# Capturing batches (bs=4 avail_mem=29.07 GB):   0%|          | 0/3 [00:00<?, ?it/s]
# Capturing batches (bs=1 avail_mem=28.93 GB): 100%|██████████| 3/3 [00:00<00:00,  4.25it/s]
# [2025-12-12 05:32:25] Endpoint '/get_model_info' is deprecated and will be removed in a future version. Please use '/model_info' instead.
# <strong style='color: #00008B;'><br><br>                    NOTE: Typically, the server runs in a separate terminal.<br>                    In this notebook, we run the server and notebook code together, so their outputs are combined.<br>                    To improve clarity, the server logs are displayed in the original black color, while the notebook outputs are highlighted in blue.<br>                    To reduce the log length, we set the log level to warning for the server, the default log level is info.<br>                    We are running those notebooks in a CI environment, so the throughput is not representative of the actual performance.<br>                    </strong>
# Server started on http://localhost:35852

# %%
set_default_backend(RuntimeEndpoint(f"http://localhost:{port}"))
# Out:
# [2025-12-12 05:32:29] Endpoint '/get_model_info' is deprecated and will be removed in a future version. Please use '/model_info' instead.

# %% [markdown]
# Ask a question about an image.

# %%
@function
def image_qa(s, image_file, question):
    s += user(image(image_file) + question)
    s += assistant(gen("answer", max_tokens=256))


image_url = "https://github.com/sgl-project/sglang/blob/main/examples/assets/example_image.png?raw=true"
image_bytes, _ = load_image(image_url)
state = image_qa(image_bytes, "What is in the image?")
print_highlight(state["answer"])
# Out:
# <strong style='color: #00008B;'>The image shows a man holding a clothes iron and what appears to be an ironing board with some clothes attached, placed on top of a dark-colored SUV in a parking or street area. The SUV is situated next to a yellow taxi, which seems to be a typical category of taxi or bus grinding remodeling, which specializes in damage repairs and thorough deep cleaning interiors 추버스그 brainstormWS heater. It appears the man might be demonstrating services offered by a taxi tempListAgE potential for formal slots alasGMTOS cPMONểnSo's GAN.</strong>

# %%
terminate_process(server_process)
