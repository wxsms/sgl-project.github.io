# %% [markdown]
# # Sending Requests
# This notebook provides a quick-start guide to use SGLang in chat completions after installation.
#
# - For Vision Language Models, see [OpenAI APIs - Vision](openai_api_vision.ipynb).
# - For Embedding Models, see [OpenAI APIs - Embedding](openai_api_embeddings.ipynb) and [Encode (embedding model)](native_api.html#Encode-(embedding-model)).
# - For Reward Models, see [Classify (reward model)](native_api.html#Classify-(reward-model)).

# %% [markdown]
# ## Launch A Server

# %%
from sglang.test.doc_patch import launch_server_cmd
from sglang.utils import wait_for_server, print_highlight, terminate_process

# This is equivalent to running the following command in your terminal
# python3 -m sglang.launch_server --model-path qwen/qwen2.5-0.5b-instruct --host 0.0.0.0

server_process, port = launch_server_cmd(
    """
python3 -m sglang.launch_server --model-path qwen/qwen2.5-0.5b-instruct \
 --host 0.0.0.0 --log-level warning
"""
)

wait_for_server(f"http://localhost:{port}")
# Out:
# [2026-01-16 13:20:37] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2026-01-16 13:20:37] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2026-01-16 13:20:37] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [2026-01-16 13:20:42] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2026-01-16 13:20:42] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2026-01-16 13:20:42] INFO utils.py:164: NumExpr defaulting to 16 threads.
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: be350ab3-8d0c-447c-a00b-88da944fbd92)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/config.json
# [2026-01-16 13:20:54] WARNING _http.py:319: '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: be350ab3-8d0c-447c-a00b-88da944fbd92)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:20:54] WARNING _http.py:328: Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 9bb74b77-d3f3-4a51-8622-e5b4211d84ac)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/config.json
# [2026-01-16 13:21:05] WARNING _http.py:319: '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 9bb74b77-d3f3-4a51-8622-e5b4211d84ac)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/config.json
# Retrying in 2s [Retry 2/5].
# [2026-01-16 13:21:05] WARNING _http.py:328: Retrying in 2s [Retry 2/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 53f9f594-4e0f-4d1d-880c-dcbcd39b1e77)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# [2026-01-16 13:21:19] WARNING _http.py:319: '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 53f9f594-4e0f-4d1d-880c-dcbcd39b1e77)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:21:19] WARNING _http.py:328: Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 9a65ac42-0ef0-43d8-8a42-d99823f58585)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/generation_config.json
# [2026-01-16 13:21:31] WARNING _http.py:319: '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 9a65ac42-0ef0-43d8-8a42-d99823f58585)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/generation_config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:21:31] WARNING _http.py:328: Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 085b6a2c-6e08-42c1-b517-c20d5f4f7e03)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/hf_quant_config.json
# [2026-01-16 13:21:43] WARNING _http.py:319: '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 085b6a2c-6e08-42c1-b517-c20d5f4f7e03)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/hf_quant_config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:21:43] WARNING _http.py:328: Retrying in 1s [Retry 1/5].
# [2026-01-16 13:21:46] INFO server_args.py:1657: Attention backend not specified. Use fa3 backend by default.
# [2026-01-16 13:21:46] INFO server_args.py:2556: Set soft_watchdog_timeout since in CI
# [2026-01-16 13:21:53] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2026-01-16 13:21:53] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2026-01-16 13:21:53] INFO utils.py:164: NumExpr defaulting to 16 threads.
# [2026-01-16 13:21:53] INFO utils.py:148: Note: detected 112 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [2026-01-16 13:21:53] INFO utils.py:151: Note: NumExpr detected 112 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2026-01-16 13:21:53] INFO utils.py:164: NumExpr defaulting to 16 threads.
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 67998a7f-3ae7-4d4a-b8e7-0cb37f7a1705)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/hf_quant_config.json
# [2026-01-16 13:21:57] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 67998a7f-3ae7-4d4a-b8e7-0cb37f7a1705)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/hf_quant_config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:21:57] Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: c9aee309-dd78-4fc8-882b-ca5fe0319261)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/hf_quant_config.json
# [2026-01-16 13:22:08] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: c9aee309-dd78-4fc8-882b-ca5fe0319261)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/hf_quant_config.json
# Retrying in 2s [Retry 2/5].
# [2026-01-16 13:22:08] Retrying in 2s [Retry 2/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 3a99bdc2-1f0e-47f6-81a3-612918256775)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# [2026-01-16 13:22:12] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 3a99bdc2-1f0e-47f6-81a3-612918256775)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:22:12] Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: f81d48bc-0235-4b7a-883c-dc359338fc05)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/hf_quant_config.json
# [2026-01-16 13:22:20] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: f81d48bc-0235-4b7a-883c-dc359338fc05)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/hf_quant_config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:22:20] Retrying in 1s [Retry 1/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: e033f52c-822e-4f58-a8a0-2b808d968e59)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# [2026-01-16 13:22:23] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: e033f52c-822e-4f58-a8a0-2b808d968e59)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# Retrying in 2s [Retry 2/5].
# [2026-01-16 13:22:23] Retrying in 2s [Retry 2/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 96079599-146e-4408-9ac3-2cafcb7c3874)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# [2026-01-16 13:22:35] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 96079599-146e-4408-9ac3-2cafcb7c3874)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen2.5-0.5B-Instruct/resolve/main/config.json
# Retrying in 4s [Retry 3/5].
# [2026-01-16 13:22:35] Retrying in 4s [Retry 3/5].
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: b23be431-0b30-487e-b10a-ab3cc33e784b)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/tokenizer_config.json
# [2026-01-16 13:22:41] '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: b23be431-0b30-487e-b10a-ab3cc33e784b)')' thrown while requesting HEAD https://huggingface.co/qwen/qwen2.5-0.5b-instruct/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].
# [2026-01-16 13:22:41] Retrying in 1s [Retry 1/5].
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [2026-01-16 13:23:06] Ignore import error when loading sglang.srt.models.glmasr: cannot import name 'GlmAsrConfig' from 'transformers' (/usr/local/lib/python3.10/dist-packages/transformers/__init__.py)
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  6.62it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  6.61it/s]
# Capturing batches (bs=4 avail_mem=52.72 GB):   0%|          | 0/3 [00:00<?, ?it/s]
# Capturing batches (bs=1 avail_mem=52.66 GB): 100%|██████████| 3/3 [00:00<00:00,  3.62it/s]
# <strong style='color: #00008B;'><br><br>                    NOTE: Typically, the server runs in a separate terminal.<br>                    In this notebook, we run the server and notebook code together, so their outputs are combined.<br>                    To improve clarity, the server logs are displayed in the original black color, while the notebook outputs are highlighted in blue.<br>                    To reduce the log length, we set the log level to warning for the server, the default log level is info.<br>                    We are running those notebooks in a CI environment, so the throughput is not representative of the actual performance.<br>                    </strong>

# %% [markdown]
# ## Using cURL

# %%
import subprocess, json

curl_command = f"""
curl -s http://localhost:{port}/v1/chat/completions \
  -H "Content-Type: application/json" \
  -d '{{"model": "qwen/qwen2.5-0.5b-instruct", "messages": [{{"role": "user", "content": "What is the capital of France?"}}]}}'
"""

response = json.loads(subprocess.check_output(curl_command, shell=True))
print_highlight(response)
# Out:
# <strong style='color: #00008B;'>{'id': 'd8f1403d74a3455f946f8b1610618c70', 'object': 'chat.completion', 'created': 1768569806, 'model': 'qwen/qwen2.5-0.5b-instruct', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'The capital of France is Paris.', 'reasoning_content': None, 'tool_calls': None}, 'logprobs': None, 'finish_reason': 'stop', 'matched_stop': 151645}], 'usage': {'prompt_tokens': 36, 'total_tokens': 44, 'completion_tokens': 8, 'prompt_tokens_details': None, 'reasoning_tokens': 0}, 'metadata': {'weight_version': 'default'}}</strong>

# %% [markdown]
# ## Using Python Requests

# %%
import requests

url = f"http://localhost:{port}/v1/chat/completions"

data = {
    "model": "qwen/qwen2.5-0.5b-instruct",
    "messages": [{"role": "user", "content": "What is the capital of France?"}],
}

response = requests.post(url, json=data)
print_highlight(response.json())
# Out:
# <strong style='color: #00008B;'>{'id': '3262d9ae74bd47c9bf13c833d5a44c67', 'object': 'chat.completion', 'created': 1768569806, 'model': 'qwen/qwen2.5-0.5b-instruct', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'The capital of France is Paris.', 'reasoning_content': None, 'tool_calls': None}, 'logprobs': None, 'finish_reason': 'stop', 'matched_stop': 151645}], 'usage': {'prompt_tokens': 36, 'total_tokens': 44, 'completion_tokens': 8, 'prompt_tokens_details': None, 'reasoning_tokens': 0}, 'metadata': {'weight_version': 'default'}}</strong>

# %% [markdown]
# ## Using OpenAI Python Client

# %%
import openai

client = openai.Client(base_url=f"http://127.0.0.1:{port}/v1", api_key="None")

response = client.chat.completions.create(
    model="qwen/qwen2.5-0.5b-instruct",
    messages=[
        {"role": "user", "content": "List 3 countries and their capitals."},
    ],
    temperature=0,
    max_tokens=64,
)
print_highlight(response)
# Out:
# <strong style='color: #00008B;'>ChatCompletion(id='5381d6458c744423800ab5473185e767', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Sure, here are three countries and their respective capitals:\n\n1. **United States** - Washington, D.C.\n2. **Canada** - Ottawa\n3. **Australia** - Canberra', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content=None), matched_stop=151645)], created=1768569806, model='qwen/qwen2.5-0.5b-instruct', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=39, prompt_tokens=37, total_tokens=76, completion_tokens_details=None, prompt_tokens_details=None, reasoning_tokens=0), metadata={'weight_version': 'default'})</strong>

# %% [markdown]
# ### Streaming

# %%
import openai

client = openai.Client(base_url=f"http://127.0.0.1:{port}/v1", api_key="None")

# Use stream=True for streaming responses
response = client.chat.completions.create(
    model="qwen/qwen2.5-0.5b-instruct",
    messages=[
        {"role": "user", "content": "List 3 countries and their capitals."},
    ],
    temperature=0,
    max_tokens=64,
    stream=True,
)

# Handle the streaming output
for chunk in response:
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end="", flush=True)
# Out:
# Sure
# ,
#  here
#  are
#  three
#  countries
#  and
#  their
#  respective
#  capitals
# :
# 1
# .
#  **
# United
#  States
# **
#  -
#  Washington
# ,
#  D
# .C
# .
# 2
# .
#  **
# Canada
# **
#  -
#  Ottawa
# 3
# .
#  **
# Australia
# **
#  -
#  Canberra

# %% [markdown]
# ## Using Native Generation APIs
#
# You can also use the native `/generate` endpoint with requests, which provides more flexibility. An API reference is available at [Sampling Parameters](sampling_params.md).

# %%
import requests

response = requests.post(
    f"http://localhost:{port}/generate",
    json={
        "text": "The capital of France is",
        "sampling_params": {
            "temperature": 0,
            "max_new_tokens": 32,
        },
    },
)

print_highlight(response.json())
# Out:
# <strong style='color: #00008B;'>{'text': ' Paris. It is the largest city in Europe and the second largest city in the world. It is located in the south of France, on the banks of the', 'output_ids': [12095, 13, 1084, 374, 279, 7772, 3283, 304, 4505, 323, 279, 2086, 7772, 3283, 304, 279, 1879, 13, 1084, 374, 7407, 304, 279, 9806, 315, 9625, 11, 389, 279, 13959, 315, 279], 'meta_info': {'id': 'de1c311a9de848e284d6ff1dd3340b74', 'finish_reason': {'type': 'length', 'length': 32}, 'prompt_tokens': 5, 'weight_version': 'default', 'total_retractions': 0, 'completion_tokens': 32, 'cached_tokens': 2, 'e2e_latency': 0.052704811096191406, 'response_sent_to_client_ts': 1768569806.5664258}}</strong>

# %% [markdown]
# ### Streaming

# %%
import requests, json

response = requests.post(
    f"http://localhost:{port}/generate",
    json={
        "text": "The capital of France is",
        "sampling_params": {
            "temperature": 0,
            "max_new_tokens": 32,
        },
        "stream": True,
    },
    stream=True,
)

prev = 0
for chunk in response.iter_lines(decode_unicode=False):
    chunk = chunk.decode("utf-8")
    if chunk and chunk.startswith("data:"):
        if chunk == "data: [DONE]":
            break
        data = json.loads(chunk[5:].strip("\n"))
        output = data["text"]
        print(output[prev:], end="", flush=True)
        prev = len(output)
# Out:
#  Paris
# .
#  It
#  is
#  the
#  largest
#  city
#  in
#  Europe
#  and
#  the
#  second
#  largest
#  city
#  in
#  the
#  world
# .
#  It
#  is
#  located
#  in
#  the
#  south
#  of
#  France
# ,
#  on
#  the
#  banks
#  of
#  the

# %%
terminate_process(server_process)
